# %%
import cv2
from pyzbar.pyzbar import decode

def decode_qr(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Use pyzbar to decode the QR code
    decoded_objects = decode(gray)
    
    for obj in decoded_objects:
        # Draw the bounding box around the detected QR code
        points = obj.polygon
        if len(points) > 4:
            hull = cv2.convexHull(points, returnPoints=True)
        else:
            hull = points

        hull = list(map(tuple, np.squeeze(hull)))
        n = len(hull)
        for j in range(0, n):
            cv2.line(image, hull[j], hull[(j + 1) % n], (0, 255, 0), 3)

        # Display the decoded QR code data
        print(f"Data: {obj.data.decode('utf-8')}")

    return image

def main():
    # Open the video capture
    cap = cv2.VideoCapture(0)

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            break

        # Decode QR code in the frame
        frame = decode_qr(frame)

        # Display the resulting frame
        cv2.imshow('QR Code Scanner', frame)

        # Exit if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the capture
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()

# %%
import cv2 
from pyzbar.pyzbar import decode
import numpy as np

def decode_qr(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Use pyzbar to decode the QR code
    decoded_objects = decode(gray)
    flip = cv2.flip(decoded_objects)
    
    for obj in flip:
        # Draw the bounding box around the detected QR code
        points = obj.polygon
        if len(points) > 4:
            hull = cv2.convexHull(np.array(points, dtype=np.float32))
        else:
            hull = points

        hull = list(map(tuple, np.squeeze(hull)))
        n = len(hull)
        for j in range(0, n):
            cv2.line(image, hull[j], hull[(j + 1) % n], (0, 255, 0), 3)

        # Display the decoded QR code data
        print(f"Data: {obj.data.decode('utf-8')}")

    return image

def main():
    # Open the video capture
    cap = cv2.VideoCapture(0)

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            break

        # Decode QR code in the frame
        frame = decode_qr(frame)

        # Display the resulting frame
        cv2.imshow('QR Code Scanner', frame)

        # Exit if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the capture
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 56
#      53     cv2.destroyAllWindows()
#      55 if __name__ == "__main__":
# ---> 56     main()
#
# Cell In[8], line 42, in main()
#      39     break
#      41 # Decode QR code in the frame
# ---> 42 frame = decode_qr(frame)
#      44 # Display the resulting frame
#      45 cv2.imshow('QR Code Scanner', frame)
#
# Cell In[8], line 11, in decode_qr(image)
#       9 # Use pyzbar to decode the QR code
#      10 decoded_objects = decode(gray)
# ---> 11 flip = cv2.flip(decoded_objects)
#      13 for obj in flip:
#      14     # Draw the bounding box around the detected QR code
#      15     points = obj.polygon
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'flip'
# > Overload resolution failed:
# >  - flip() missing required argument 'flipCode' (pos 2)
# >  - flip() missing required argument 'flipCode' (pos 2)

# %%
import cv2 
from pyzbar.pyzbar import decode
import numpy as np

def decode_qr(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Use pyzbar to decode the QR code
    decoded_objects = decode(gray)
    
    for obj in decoded_objects:
        # Draw the bounding box around the detected QR code
        points = obj.polygon
        if len(points) > 4:
            hull = cv2.convexHull(np.array(points, dtype=np.float32))
        else:
            hull = points

        hull = list(map(tuple, np.squeeze(hull)))
        n = len(hull)
        for j in range(0, n):
            cv2.line(image, hull[j], hull[(j + 1) % n], (0, 255, 0), 3)

        # Display the decoded QR code data
        print(f"Data: {obj.data.decode('utf-8')}")

    return image

def main():
    # Open the video capture
    cap = cv2.VideoCapture(0)

    while True:
        # Capture frame-by-frame
        ret, frame = cap.read()
        if not ret:
            break

        # Decode QR code in the frame
        frame = decode_qr(frame)

        # Display the resulting frame
        cv2.imshow('QR Code Scanner', frame)

        # Exit if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything is done, release the capture
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
